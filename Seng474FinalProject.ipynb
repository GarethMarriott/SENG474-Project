# %% [markdown]
# <br> </br>
# <br> </br>
# <br> </br>
#
#
#  <p style="text-align:center; font-size:24px; line-height: 1.2"> <b> Towards Discovering Trends in Player
#     Point Statistics <br> using National Football League Data: <br>A Data Mining Approach </b></p>
#
# <br> </br>
# <br> </br>
# <br> </br>
#
# <div style="text-align:center"> Seng 474: Data Mining <br>
# Final Project By: <br>
# Gareth Marriott (V00875748) and Roxanne Dewing (V00853942)</div>
#
# <br> </br>
#
#
# <div style="text-align:center; font-size:24px"> <b>Abstract</b> </div>
# <br> </br>
#
# <div style="text-align:center; margin-right: 70px; margin-left: 70px;">
# With the 32 NFL franchises having a net value of 74.8 billion, it is of interest to examine and identify statistical trends amongst the teams and players. Furthermore, the AGA estimated that a total of 95 billion was wagered on the National Football League during the 2015 season. We argue that a players earned points during various weeks can determine the points that player will score on the next upcoming week. Indeed, we found after data collection, pre-processing and applying linear regression data mining techniques, specifically Perceptron, that this is true. These predictions have various applications, the main one being Fantasy Football.
# </div>
# <br> </br>
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:22px">
#  <b>Contents</b>
# </div>
#
# > 1. Introduction
#
# <div style=" margin-left: 100px">
#
#    1.1 Fantasy Football <br>
#
#    1.2 Perceptron <br>
#
#    1.3 Problem and Proposed Solution <br>
#
# </div>
#
# > 2. Related Work
#
# > 3. Data Pre-processing and Visualization (Non-trivial)
#
# <div style=" margin-left: 100px">
#
#    3.1 Obtaining the data <br>
#
#    3.2 Cleaning the data <br>
#
#    3.3 Grouping the data <br>
#
# </div>
#
# > 4. Data Mining (Perceptron)
#
# > 5. Conclusions
#
# > 6. References
#
#
#
#
#
# <br> </br>
# <br> </br>
# <br> </br>
#
#
# <div style="margin-right: 70px; margin-left: 70px; font-size:22px">
#  <b>Introduction </b>
#    </div>
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#
#    <b> Fantasy Football </b>
#
# </div>
#
# <div style="margin-right: 70px; margin-left: 70px">
#     <br>
# Fantasy Football is a web based game in which players are the managers of fake North American Football teams. The players choose their team rosters and the competition can run either for an entire season or over shorter periods, such as a week or a single day (wikipedia).
# <br>
#     <br>
# Currently, the daily fantasy football game model is the most popular. However, risking money on the outcome of a sporting event constitutes gambling, which is illegal. But in fantasy football, participants are betting on individual players, not on the game. The number of people playing fantasy sports this year in the United States and Canada is 56.8 million people and increasing.
#
# </div>
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#
#    <b> Perceptron </b>
#
# </div>
# <div style="margin-right: 70px; margin-left: 70px">
#     <br>
# The linear regression technique, Perceptron, was invented by Frank Rosenblatt in the 1950s at the Calspan. The perceptron is a simplified model of a biological neuron. The learning algorithm is separated into two parts, those being the training phase and the recall phase.
#
# </div>
#
# <br> </br>
#   <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#
#    <b> Problem and proposed solution </b>
#
# </div>
# <br> </br>
#
#  <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
# Because of the persistent and increasing interest in fantasy football, along with the AGA estimated total of 95 billion wagered on the NFL during the 2015 season, we have decided to look further into how to choose players while playing. We argue that a players points during various weeks can determine the points that player will score on the next upcoming week.
# To determine the points that player will score on the next upcoming week, we applied data mining techniques that learned on all players in the previous weeks. Specifically, we use the Perceptron algorithm.
# </div>
# <br> </br>
#
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:22px">
#  <b>Related Work </b>
#    </div>
#    <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
# Using machine learning techniques has become more and more popular amongst sports fans. In fact, Artificial Neural Networks are the most commonly applied approach among machine learning mechanisms to the sport result prediction problem (Bunker, Thabtah 2017).
#
# Originally, the basic goals for neural network related work were centered around brain modelling (with the scientific purpose of discovering how real brains work), and artificial system building (relieving humans of tedious tasks). However, neural networks, specifically Perceptron (which is a single-layered neural network), has been used for many applications such as financial prediction, airline marketing tactician and speech recognition.
#
# In terms of the National Football League, there have been many prediction studies conducted. Purucker conducted one of the initial studies using an ANN model. He used Data from the first eight rounds of the competition. He also used various features such as yards gained, rushing yards gained, turnover margin, time of possession, and betting line odds (Bunker, Thabtah 2017). Purucker achieved 61% accuracy compared with 72% accuracy of the domain experts.
#
# Kahn extended the work of Purucker and achieved greater accuracy, performing slightly better than experts in the NFL who were making predictions on the same games. Data on 208 matches in the 2003 season were collected. The features that were used were: total yardage differential, rushing yardage differential, turnover differential, away team indicator and home team indicator (Bunker, Thabtah 2017). Accuracy of 75% was achieved across the week 14 and 15 matches.
# </div>
# <br> </br>
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:22px">
#  <b>Data Preprocessing and Visualization </b>
#    </div>
#
#    <br> </br>
#   <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#
#    <b> Obtaining the data: </b>
#
# </div>
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#
# The Python 3 code in notebook entry 3 accepts the season year and week number as arguments. When the URL is queried, the data is initially in the form of a list, however, each element of the list is a dictionary with keys and values as such:
#
# </div>
#
# <br> </br>
# <br> </br>
#
# <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
#  {
# "id": "id number", <br>
# "esbid': "None", <br>
# "gsisPlayerId": "False | True", <br>
# "name": "name of team", <br>
# "position": "DEF | OL | LB | DB", <br>
# "teamAbbr": "abbreviation of team name", <br>
# "stats": "dictionary of stat number as key and stat as value",<br>
#  "seasonPts": "number of season points",<br>
#  "seasonProjectedPts": "number of season projected points", <br>
# "weekPts": "week points",<br>
#  "weekProjectedPts": "week projected points"}<br>
#
# </div>
#
# <br> </br>
#   <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#
#    <b> Cleaning the data: </b>
#
# </div>
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
# Within each player dictionary, the dictionary as the value to the stats entry has keys that represent the stat number and the value as such. Since the stat numbers range from 1 - 91, and offer no description, a lookup list called CONVERSION_TABLE is used for each player. The list has each element as a dictionary, each entry having the key holding the stat number, and the description of what the stat represents.
# </div>
# <br> </br>
#
#
# <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
#           {
# "id":81, <br>
#               "abbr":"PDef", <br>
#               "name":"Pass Defended", <br>
#               "shortName":"Pass Def"} <br>
#
# </div>
#
# <br> </br>
#
# <br> </br>
#
# <div style="margin-right: 70px; margin-left: 70px; font-size:22px">
#  <b>Data Mining </b>
#    </div>
#    <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#    Once we prepared the data, we use the Perceptron in two different ways so that we can see the variance in accuracy amongst different splits of the data. We first trained the perceptron on all the quarterbacks from 2010 to 2016. Using this model, we tested on the Quarterback data from 2017 and found the mean squared error. Another approach we took  was training the perceptron on a random 70 percent of the data, and then training the perceptron on the remaining 30 percent of the data.
#
#
# </div>
#
# <br> </br>
#
#   <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#
#    <b> Training on 2010 through till 2016 and testing on 2017 </b>
#
# </div>
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
# Once we got our data in the proper form, we were able to use Pythons scikit learn library. We created an instance of a perceptron object (clf), and set the number of iterations to 40, the stopping criterion to 0.001 and the random_state variable to 0.
#
# </div>
# <br> </br>
#
# <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre> clf = Perceptron(n_iter=40 , tol=1e-3, random_state=0)  </pre>
# </div>
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
# We gathered the data for each individual player who is a quarterback in 2010 through till 2016 (see data pre-processing section).
#
# We then passed the QB_data and the QB_results to the Perceptron objects “fit” method. This method fits the linear model with the Stochastic Gradient Descent.
#
# </div>
# <br> </br>
# <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre> clf.fit(QB_data, QB_results) </pre>
# </div>
#
#
# <br> </br>
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#
#  We then called the Perceptron objects predict method which predict class labels for samples in X.
#  </div>
#  <br> </br>
#
#  <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre> predictions = clf.predict(QB_data) </pre>
# </div>
#
#   <br> </br>
#
#
#   <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#     After calling predict, we were able to find the mean squared error, 141.69, for the week 2017 data based on the 2010-2016 data.
#     </div>
#
# <br> </br>
#
#  <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre> mean_squared_error(y_test , y_pred) </pre>
# </div>
#
# <br> </br>
#
#   <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#
#    <b> Training on 70 percent and testing on remaining 30 percent </b>
#
# </div>
# <br> </br>
#  <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#     Similarly, our QB_data contained all data (pre-processed) from years 2010 up to and now including 2017. We gathered all the results to be tested against in the same order.
#     </div>
#    <br> </br>
#   <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre> QB_results = gather_QB_results(QB_data , str(i))</pre>
# </div>
#
#
# <br> </br>
#  <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#     And for each year we appended to train_data and data_label arrays
#  </div>
#  <br> </br>
#
#  <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre> for val in QB_data: <br>
#          train_data.append(val)</pre>
# </div>
#  <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre> for val in QB_results: <br>
#          data_label.append(val)</pre>
# </div>
#   <br> </br>
#
#
#
#    <br> </br>
#   <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#   We then standardized the dataset, as it  is a common requirement for many machine learning estimators:
#  </div>
#  <br> </br>
#   <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre>sc =  StandardScaler()<br>sc.fit(x_train)</pre>
# </div>
#
#
#
# <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre>x_train = sc.transform(x_train)<br>x_test = sc.transform(x_test)</pre>
# </div>
#
#   <br> </br>
#
#    <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
# We then split the data as such:
#  </div>
#   <br> </br>
#  <div style="margin-right: 70px; margin-left: 130px; font-size:13px">
# <pre>x_train, x_test, y_train, y_test = train_test_split(train_data, data_label, test_size=0.3)</pre>
# </div>
#
#
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
# We created another perceptron instance, clf, with 40 iterations and fit it as such:
#  </div>
#
#  <br> </br>
#
#   <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre>clf.fit(x_train, y_train)</pre>
# </div>
#
#
# <br> </br>
#    <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
# We then Applied the trained perceptron on the X data to make predictions for the y test data
#  </div>
#   <br> </br>
#    <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre>y_pred = clf.predict(x_test)</pre>
# </div>
#
#
#   <br> </br>
#
# <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
# Finally, we were able to compute the mean squared error
#
#  </div>
#
# <div style="margin-right: 70px; margin-left: 130px; font-size:14px">
# <pre>mean_squared_error(y_test , y_pred)</pre>
# </div>
#
#   <br> </br>
#
#    <div style="margin-right: 70px; margin-left: 70px; font-size:22px">
#  <b>Conclusions </b>
#    </div>
#    <br> </br>
#    <div style="margin-right: 70px; margin-left: 70px; font-size:14px">
#     As mentioned, fantasy football is a multi-million dollar industry with major growth potential. Our project focused on the retrieval of fantasy football data, as well as historical stat data, to predict fantasy football points with Perceptron. Future work could include many changes and extensions to our project. On the technical side, a logical next step would be to extend the model and predict any week of the football season using the previous 8 weeks of data. However, due to the scope of our project, we focused on the second last week of the season and the previous weeks in that year to get an idea of how well the model performs. <br>
#
# On the theoretical side, we found that the accuracy of the integer predictions made by the model were not great. However, when looked at through the lens of mean squared error the results were more promising. Due to the natural high variance in football stats, the model had a tough time predicting the exact integer values of the players. Despite this, the model was able to approximate the values of fantasy points fairly well. In a continuation of the project, one could look at other algorithms and their mean squared error results. Based off of this data, the model could be further generalized.
#
#
#  </div>
#    <br> </br>
#   <div style="margin-right: 70px; margin-left: 70px; font-size:22px">
#  <b>References </b>
#    </div>
#
#    <br> </br>
#   <div style="margin-right: 70px; margin-left: 70px; font-size:14px">1. Bunker, Rory P., and Fadi Thabtah. “A Machine Learning Framework for Sport Result Prediction.” Applied Computing and Informatics, 2017, doi:10.1016/j.aci.2017.09.005.<br> <br>2. “Fantasy Football (American).” Wikipedia, Wikimedia Foundation, 4 Dec. 2018, en.wikipedia.org/wiki/Fantasy_football_(American).<br> <br>3. “Perceptron.” Wikipedia, Wikimedia Foundation, 26 Nov. 2018, en.wikipedia.org/wiki/Perceptron.
#
#
#  </div>
#
#   <div style="margin-right: 70px; margin-left: 70px; font-size:22px">

# %%
The module below, scrapes the fantasy football API, and obtains the data for a specified week and year

# %%
# November 20 2018
# Gareth Marriott (V00875748)
# Roxane Dewing (V00853942)
# Gathers nfl statistic data from the public api.fantasy.nfl
# Docs can be found at https://api.fantasy.nfl.com/v1/docs/service?serviceName=playersStats


import sys
from urllib.request import urlopen
import json



#makes a dictionary for each player and their stats, also calls coversion table to replace 
#abberviated statistics with full descriptive names: ex "id: 85" -> "QB Hit"
def prosses_player_data(x):
    player = {}
    player["name"] = x["name"]
    player["position"] = x["position"]
    player["team"] = x["teamAbbr"]
    for stat in x["stats"]:
        for type in CONVERSION_TABLE:
            if str(type["id"]) == str(stat):
                player.update({type["name"] : x["stats"][stat]})

    return player


def obtain_data(fin_d):
    
    
    #modify which year you would like statistics from
    year = "2017"
    
    #modify which week you would like statistics from
    week = 1
    
    #optains the correct URL in string format
    for year in range (2014, 2017):
        print("Year "+ str(year))
        for week in range(1, 7):
            year_str = str(year)
            week_str = str(week)
            url = 'https://api.fantasy.nfl.com/v1/players/stats?statType=weekStats&season='+year_str+'&week='+week_str+'&format=json'

            #Quiries the API
            html = urlopen(url).read()

            d = json.loads(html)['players']

            #filter so that only Quarter backs are considered
            d = list(filter(lambda x: str(x['position']) == 'QB' , d))
            #calls process_player_data that makes a dictionary of player information for each player
            d = list(map(lambda x: prosses_player_data(x),d))
            print("Week number "+str(week))
            print("Found data for " + str(len(d)) + " players")
            fin_d.append(d)
    return fin_d



fin_d = []
obtain_data(fin_d)
print("\n")
print("Example data for Year 2017 week 1: ")
print("\n")
print(fin_d[0])

# %%
The cell below, is further data pre processing and implements the Perceptron

# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.linear_model import Perceptron
import json
import ast
import sys
from sklearn import datasets
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# X, y = load_digits(return_X_y=True)
# clf = Perceptron(tol=1e-3, random_state=0)
# clf.fit(X, y)
#
# clf.score(X, y)


def gather_QB_results(players , year):
    # print(year)
    data = open("point-results-"+year+".txt").read()
    data = ast.literal_eval(data)
    output = []
    for player in players:
        for points in data:
            # print(player)
            if player[0] in points:
                output.append([player[0] , points[player[0]]])

    # print(output)
    return output


def prep_data(stats):
    # The standard order each week of stats will be arranged
    structure = ["Passing Attempts","Passing Completions","Incomplete Passes","Passing Yards","Passing Touchdowns","Interceptions Thrown","Rushing Attempts","Rushing Yards","Rushing Touchdowns"]
    #
    output = [stats[0]]
    # print(stats)
    for stat in structure:
        iterstats = iter(stats)
        next(iterstats)
        for week in iterstats:
            if stat in week:
                output.append(str(week[stat]))
            else:
                output.append(0)
    return output

def gather_QB_data(year):
    # Open the week 16 data file of specified year and convert to JSON
    # Since we are using week 16 as test data
    # We will only gather QB data from the other weeks if we have data from week 16
    data = open("./data/"+year+"-16.txt").read()
    data = ast.literal_eval(data)

    # Add each QB's name to a list
    players = []
    for player in data:
        if player["position"] == "QB":
            players.append([player["name"]])

    # Iterate over each week and open that weeks data
    for week in range(1,16):
        # Open the file associated with the week and year and convert to JSON
        data = open("./data/"+year+"-"+str(week)+".txt").read()
        data = ast.literal_eval(data)

        # Check each players data in the weekly data
        # If they are in the QB list append their data to that QB list
        for player_weekly in data:
            for player in players:
                if player[0] == player_weekly["name"]:
                    player.append(player_weekly)

    # Only accept QB data from people who played every week
    players = list(filter(lambda x: len(x) > 14 , players))

    # Convert the player from a name and a dictionary to in a list to just a list of data
    prepared_data = list(map(lambda x: prep_data(x) , players))

    return prepared_data


def test_2017():

    clf = Perceptron(n_iter=40 , tol=1e-3, random_state=0)

    # Iterate through each year of data
    for i in range(2010,2017):
        # Gather the data for each player in a list, The first value of each sub list will be the players name
        # each players data will be in a sublist orginized in a format specified in the function
        QB_data = gather_QB_data(str(i))

        # Gather all the values to be tested agianst
        # in the same order as the players data given by as an argument
        QB_results = gather_QB_results(QB_data , str(i))


        QB_data = list(map(lambda x: x[1:] , QB_data))
        QB_data = list(map(lambda x: list(map(lambda x: int(x) , x)) , QB_data))

        QB_results = list(map(lambda x: str(round(x[1])) , QB_results))

        # sc = StandardScaler()
        # sc.fit(QB_data)

        # QB_data = sc.transform(QB_data)

        clf.fit(QB_data, QB_results)

    QB_data = gather_QB_data("2017")
    print(len(QB_data))
    QB_results = gather_QB_results(QB_data , "2017")
    print(len(QB_results))

    QB_data = list(map(lambda x: x[1:] , QB_data))
    QB_data = list(map(lambda x: list(map(lambda x: int(x) , x)) , QB_data))
    QB_results = list(map(lambda x: str(round(x[1])) , QB_results))

    predictions = clf.predict(QB_data)

    y_pred = list(map(lambda x: int(x) , predictions))
    y_test = list(map(lambda x: int(x) , QB_results))

    print("mean squared error: %.2f" % mean_squared_error(y_test , y_pred))


def test_random():

    train_data = []
    data_label = []
    for i in range(2010,2018):
        QB_data = gather_QB_data(str(i))
        # print(len(QB_data))
        QB_results = gather_QB_results(QB_data , str(i))
        # print(len(QB_results))

        QB_data = list(map(lambda x: x[1:] , QB_data))

        QB_data = list(map(lambda x: list(map(lambda x: int(x) , x)) , QB_data))
        QB_results = list(map(lambda x: str(round(x[1])) , QB_results))
        for val in QB_data:
            train_data.append(val)
        for val in QB_results:
            data_label.append(val)

    x_train, x_test, y_train, y_test = train_test_split(train_data, data_label, test_size=0.3)

    sc = StandardScaler()
    sc.fit(x_train)

    x_train = sc.transform(x_train)
    x_test = sc.transform(x_test)

    # clf = Perceptron(n_iter=60, eta0=0.1, random_state=0)
    clf = Perceptron(n_iter=40 , tol=1e-3, random_state=0)

    clf.fit(x_train, y_train)

    #Apply the trained perceptron on the X data to make predicts for the y test data
    y_pred = clf.predict(x_test)

    for pred,test in zip(y_pred,y_test):
        print(pred + " : " + test)

    print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

    y_pred = list(map(lambda x: int(x) , y_pred))
    y_test = list(map(lambda x: int(x) , y_test))

    print("mean squared error: %.2f" % mean_squared_error(y_test , y_pred))


def main():
    # Training Perceptron on all the quarterback data from 2010-2016
    # Testing on the QB data from 2017
    test_2017()

    # Training Perceptron on a random 70% of the data availible
    # Testing Perceptron on the remaining 30% of data availible
    test_random()

main()

# %%
The cell below is a Conversion table we used to eliminate abbreviations in our data and replace with a full 
descriptive name

# %%
CONVERSION_TABLE = [
        {
          "id":1,
          "abbr":"GP",
          "name":"Games Played",
          "shortName":"GP"
        },
        {
          "id":2,
          "abbr":"Att",
          "name":"Passing Attempts",
          "shortName":"Pass Att"
        },
        {
          "id":3,
          "abbr":"Comp",
          "name":"Passing Completions",
          "shortName":"Pass Comp"
        },
        {
          "id":4,
          "abbr":"Inc",
          "name":"Incomplete Passes",
          "shortName":"Pass Inc"
        },
        {
          "id":5,
          "abbr":"Yds",
          "name":"Passing Yards",
          "shortName":"Pass Yds"
        },
        {
          "id":6,
          "abbr":"TD",
          "name":"Passing Touchdowns",
          "shortName":"Pass TD"
        },
        {
          "id":7,
          "abbr":"Int",
          "name":"Interceptions Thrown",
          "shortName":"Pass Int"
        },
        {
          "id":8,
          "abbr":"Sacked",
          "name":"Every Time Sacked",
          "shortName":"Sacked"
        },
        {
          "id":9,
          "abbr":"300-399",
          "name":"300-399 Passing Yards Bonus",
          "shortName":"300-399 Pass Yds"
        },
        {
          "id":10,
          "abbr":"400+",
          "name":"400+ Passing Yards Bonus",
          "shortName":"400+ Pass Yds"
        },
        {
          "id":11,
          "abbr":"40+ TD",
          "name":"40+ Passing Yard TD Bonus",
          "shortName":"40+ Pass TD"
        },
        {
          "id":12,
          "abbr":"50+ TD",
          "name":"50+ Passing Yards TD Bonus",
          "shortName":"50+ Pass TD"
        },
        {
          "id":13,
          "abbr":"Att",
          "name":"Rushing Attempts",
          "shortName":"Rush Att"
        },
        {
          "id":14,
          "abbr":"Yds",
          "name":"Rushing Yards",
          "shortName":"Rush Yds"
        },
        {
          "id":15,
          "abbr":"TD",
          "name":"Rushing Touchdowns",
          "shortName":"Rush TD"
        },
        {
          "id":16,
          "abbr":"40+ TD",
          "name":"40+ Rushing Yard TD Bonus",
          "shortName":"40+ Rush TD"
        },
        {
          "id":17,
          "abbr":"50+ TD",
          "name":"50+ Rushing Yard TD Bonus",
          "shortName":"50+ Rush TD"
        },
        {
          "id":18,
          "abbr":"100-199",
          "name":"100-199 Rushing Yards Bonus",
          "shortName":"100-199 Rush Yds"
        },
        {
          "id":19,
          "abbr":"200+",
          "name":"200+ Rushing Yards Bonus",
          "shortName":"200+ Rush Yds"
        },
        {
          "id":20,
          "abbr":"Rect",
          "name":"Receptions",
          "shortName":"Receptions"
        },
        {
          "id":21,
          "abbr":"Yds",
          "name":"Receiving Yards",
          "shortName":"Rec Yds"
        },
        {
          "id":22,
          "abbr":"TD",
          "name":"Receiving Touchdowns",
          "shortName":"Rec TD"
        },
        {
          "id":23,
          "abbr":"40+ TD",
          "name":"40+ Receiving Yard TD Bonus",
          "shortName":"40+ Rec TD"
        },
        {
          "id":24,
          "abbr":"50+ TD",
          "name":"50+ Receiving Yard TD Bonus",
          "shortName":"50+ Rec TD"
        },
        {
          "id":25,
          "abbr":"100-199",
          "name":"100-199 Receiving Yards Bonus",
          "shortName":"100-199 Rec Yds"
        },
        {
          "id":26,
          "abbr":"200+",
          "name":"200+ Receiving Yards Bonus",
          "shortName":"200+ Rec Yds"
        },
        {
          "id":27,
          "abbr":"Yds",
          "name":"Kickoff and Punt Return Yards",
          "shortName":"Return Yds"
        },
        {
          "id":28,
          "abbr":"TD",
          "name":"Kickoff and Punt Return Touchdowns",
          "shortName":"Return TD"
        },
        {
          "id":29,
          "abbr":"Fum TD",
          "name":"Fumble Recovered for TD",
          "shortName":"Fum TD"
        },
        {
          "id":30,
          "abbr":"Lost",
          "name":"Fumbles Lost",
          "shortName":"Fum Lost"
        },
        {
          "id":31,
          "abbr":"Fum",
          "name":"Fumble",
          "shortName":"Fum"
        },
        {
          "id":32,
          "abbr":"2PT",
          "name":"2-Point Conversions",
          "shortName":"2PT"
        },
        {
          "id":33,
          "abbr":"Made",
          "name":"PAT Made",
          "shortName":"PAT Made"
        },
        {
          "id":34,
          "abbr":"Miss",
          "name":"PAT Missed",
          "shortName":"PAT Miss"
        },
        {
          "id":35,
          "abbr":"0-19",
          "name":"FG Made 0-19",
          "shortName":"FG 0-19"
        },
        {
          "id":36,
          "abbr":"20-29",
          "name":"FG Made 20-29",
          "shortName":"FG 20-29"
        },
        {
          "id":37,
          "abbr":"30-39",
          "name":"FG Made 30-39",
          "shortName":"FG 30-39"
        },
        {
          "id":38,
          "abbr":"40-49",
          "name":"FG Made 40-49",
          "shortName":"FG 40-49"
        },
        {
          "id":39,
          "abbr":"50+",
          "name":"FG Made 50+",
          "shortName":"FG 50+"
        },
        {
          "id":40,
          "abbr":"0-19",
          "name":"FG Missed 0-19",
          "shortName":"FG Miss 0-19"
        },
        {
          "id":41,
          "abbr":"20-29",
          "name":"FG Missed 20-29",
          "shortName":"FG Miss 20-29"
        },
        {
          "id":42,
          "abbr":"30-39",
          "name":"FG Missed 30-39",
          "shortName":"FG Miss 30-39"
        },
        {
          "id":43,
          "abbr":"40-49",
          "name":"FG Missed 40-49",
          "shortName":"FG Miss 40-49"
        },
        {
          "id":44,
          "abbr":"50+",
          "name":"FG Missed 50+",
          "shortName":"FG Miss 50+"
        },
        {
          "id":45,
          "abbr":"Sack",
          "name":"Sacks",
          "shortName":"Sack"
        },
        {
          "id":46,
          "abbr":"Int",
          "name":"Interceptions",
          "shortName":"Int"
        },
        {
          "id":47,
          "abbr":"Fum Rec",
          "name":"Fumbles Recovered",
          "shortName":"Fum Rec"
        },
        {
          "id":48,
          "abbr":"Fum F",
          "name":"Fumbles Forced",
          "shortName":"Fum Forc"
        },
        {
          "id":49,
          "abbr":"Saf",
          "name":"Safeties",
          "shortName":"Saf"
        },
        {
          "id":50,
          "abbr":"TD",
          "name":"Touchdowns",
          "shortName":"TD"
        },
        {
          "id":51,
          "abbr":"Block",
          "name":"Blocked Kicks",
          "shortName":"Block"
        },
        {
          "id":52,
          "abbr":"Yds",
          "name":"Kickoff and Punt Return Yards",
          "shortName":"Return Yds"
        },
        {
          "id":53,
          "abbr":"TD",
          "name":"Kickoff and Punt Return Touchdowns",
          "shortName":"Return TD"
        },
        {
          "id":54,
          "abbr":"Pts Allow",
          "name":"Points Allowed",
          "shortName":"Pts Allow"
        },
        {
          "id":55,
          "abbr":"Pts Allow",
          "name":"Points Allowed 0",
          "shortName":"Pts Allow 0"
        },
        {
          "id":56,
          "abbr":"Pts Allow",
          "name":"Points Allowed 1-6",
          "shortName":"Pts Allow 1-6"
        },
        {
          "id":57,
          "abbr":"Pts Allow",
          "name":"Points Allowed 7-13",
          "shortName":"Pts Allow 7-13"
        },
        {
          "id":58,
          "abbr":"Pts Allow",
          "name":"Points Allowed 14-20",
          "shortName":"Pts Allow 14-20"
        },
        {
          "id":59,
          "abbr":"Pts Allow",
          "name":"Points Allowed 21-27",
          "shortName":"Pts Allow 21-27"
        },
        {
          "id":60,
          "abbr":"Pts Allow",
          "name":"Points Allowed 28-34",
          "shortName":"Pts Allow 28-34"
        },
        {
          "id":61,
          "abbr":"Pts Allowed",
          "name":"Points Allowed 35+",
          "shortName":"Pts Allowed 35+"
        },
        {
          "id":62,
          "abbr":"Yds Allow",
          "name":"Yards Allowed",
          "shortName":"Yds Allow"
        },
        {
          "id":63,
          "abbr":"0-99 Yds",
          "name":"Less than 100 Total Yards Allowed",
          "shortName":"Less 100 Yds Allowed"
        },
        {
          "id":64,
          "abbr":"100-199 Yds",
          "name":"100-199 Yards Allowed",
          "shortName":"100-199 Yds Allow"
        },
        {
          "id":65,
          "abbr":"200-299 Yds",
          "name":"200-299 Yards Allowed",
          "shortName":"200-299 Yds Allow"
        },
        {
          "id":66,
          "abbr":"300-399 Yds",
          "name":"300-399 Yards Allowed",
          "shortName":"300-399 Yds Allow"
        },
        {
          "id":67,
          "abbr":"400-449 Yds",
          "name":"400-449 Yards Allowed",
          "shortName":"400-449 Yds Allow"
        },
        {
          "id":68,
          "abbr":"450-499 Yds",
          "name":"450-499 Yards Allowed",
          "shortName":"450-499 Yds Allow"
        },
        {
          "id":69,
          "abbr":"500+ Yds",
          "name":"500+ Yards Allowed",
          "shortName":"500+ Yds Allow"
        },
        {
          "id":70,
          "abbr":"Tot",
          "name":"Tackle",
          "shortName":"Tack"
        },
        {
          "id":71,
          "abbr":"Ast",
          "name":"Assisted Tackles",
          "shortName":"Ast"
        },
        {
          "id":72,
          "abbr":"Sck",
          "name":"Sack",
          "shortName":"Sack"
        },
        {
          "id":73,
          "abbr":"Int",
          "name":"Defense Interception",
          "shortName":"Int"
        },
        {
          "id":74,
          "abbr":"Frc Fum",
          "name":"Forced Fumble",
          "shortName":"Frc Fum"
        },
        {
          "id":75,
          "abbr":"Fum Rec",
          "name":"Fumbles Recovery",
          "shortName":"Fum Rec"
        },
        {
          "id":76,
          "abbr":"Int TD",
          "name":"Touchdown (Interception return)",
          "shortName":"Int TD"
        },
        {
          "id":77,
          "abbr":"Fum TD",
          "name":"Touchdown (Fumble return)",
          "shortName":"Fum TD"
        },
        {
          "id":78,
          "abbr":"Blk TD",
          "name":"Touchdown (Blocked kick)",
          "shortName":"Blk TD"
        },
        {
          "id":79,
          "abbr":"Blk",
          "name":"Blocked Kick (punt, FG, PAT)",
          "shortName":"Blk"
        },
        {
          "id":80,
          "abbr":"Saf",
          "name":"Safety",
          "shortName":"Saf"
        },
        {
          "id":81,
          "abbr":"PDef",
          "name":"Pass Defended",
          "shortName":"Pass Def"
        },
        {
          "id":82,
          "abbr":"Int Yds",
          "name":"Interception Return Yards",
          "shortName":"Int Yds"
        },
        {
          "id":83,
          "abbr":"Fum Yds",
          "name":"Fumble Return Yards",
          "shortName":"Fum Yds"
        },
        {
          "id":84,
          "abbr":"TFL",
          "name":"Tackles for Loss Bonus",
          "shortName":"TFL"
        },
        {
          "id":85,
          "abbr":"QB Hit",
          "name":"QB Hit",
          "shortName":"QB Hit"
        },
        {
          "id":86,
          "abbr":"Sck Yds",
          "name":"Sack Yards",
          "shortName":"Sck Yds"
        },
        {
          "id":87,
          "abbr":"10+ Tackles",
          "name":"10+ Tackles Bonus",
          "shortName":"10+ Tack"
        },
        {
          "id":88,
          "abbr":"2+ Sacks",
          "name":"2+ Sacks Bonus",
          "shortName":"2+ Sck"
        },
        {
          "id":89,
          "abbr":"3+ Passes Defended",
          "name":"3+ Passes Defended Bonus",
          "shortName":"3+ Pas Def"
        },
        {
          "id":90,
          "abbr":"50+ Yard INT Return TD",
          "name":"50+ Yard INT Return TD Bonus",
          "shortName":"50+ Yard INT TD"
        },
        {
          "id":91,
          "abbr":"50+ Yard Fumble Return TD",
          "name":"50+ Yard Fumble Return TD Bonus",
          "shortName":"50+ Yard Fum Ret TD"
        }
      ]
